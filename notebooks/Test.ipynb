# %%
import os
import gzip
import shutil

def ungzip_metdata(dir_path, file_type):
    """Iterate over the `path_dir` and its children and
    ungizp the .gz metadata files found.
    """
    metadata_list = []

    for subdir, dirs, files in os.walk(dir_path, topdown=True):
        for file in files:
            # logger.debug(f"{file}")
            filepath = subdir + os.sep + file
            if filepath.endswith(str(file_type)):
                metadata_list.append(filepath)
                with gzip.open(filepath, "rb") as f, open(filepath + ".xml", "wb") as r:
                    shutil.copyfileobj(f, r, 65536)
    return metadata_list

# %%
list = ungzip_metdata("/Users/leonardovida/dev/hist-aware/data/raw/delpher/1960s", '.gz')

# %%
list[1:2]
# Out:
# ['/Users/leonardovida/dev/hist-aware/data/raw/delpher/1960s/1967/04-27/DDD_110590220/DDD:ddd:110590220:mpeg21.didl.xml.gz']

# %%
import re 
from datetime import datetime
import pathlib
import pprint
import xmltodict
from functools import reduce

def parse_XML_metadata(path, met_dir, title, index):
    """Parse the input XML file and store the result in a pandas
    DataFrame with the given columns.

    Takes the filepath, file title and index integer of the df
    """
    metadata = {}
    list_metadata = []
    list_articles = []

    # Parse the date with regex
    match = re.search(r"\d{4}[/]\d{2}[-]\d{2}", path)
    date = datetime.strptime(match.group(), "%Y/%m-%d").date()

    # Parse DIDL XML
    with open(pathlib.Path(path), "r") as f:
        file = f.read()
        doc = xmltodict.parse(file)
        temp_data = doc["didl:DIDL"]["didl:Item"]["didl:Component"][0]["didl:Resource"][
            "srw_dc:dcx"
        ]
        pages = doc["didl:DIDL"]["didl:Item"]#["didl:Item"]

    metadata["metadata_title"] = title
    metadata["date"] = date
    metadata["index"] = index
    metadata["filepath"] = path
    metadata["dir"] = met_dir

    # Retrieve informations about the newspaper
    metadata["newspaper_title"] = deep_get(temp_data, "dc:title")
    metadata["newspaper_date"] = deep_get(temp_data, "dc:date")
    metadata["newspaper_publisher"] = deep_get(temp_data, "dc:publisher")
    metadata["newspaper_source"] = deep_get(temp_data, "dc:source")
    metadata["newspaper_volume"] = deep_get(temp_data, "dcx:volume")
    metadata["newspaper_issuenumber"] = deep_get(temp_data, "dcx:issuenumber")
    metadata["newspaper_recordIdentifier"] = deep_get(temp_data, "dcx:recordIdentifier")
    
    for page in range(len(pages["didl:Item"])):
        p = pages["didl:Item"][page]
        try:
            articles = p["didl:Item"]
            for article in range(len(articles)):
                article_dict = {}
                art = articles[article]
                article_dict["subject"] = art["didl:Component"][0]["didl:Resource"]["srw_dc:dcx"]["dc:subject"]
                article_dict["title"] = art["didl:Component"][0]["didl:Resource"]["srw_dc:dcx"]["dc:title"]
                article_dict["access_rights"] = art["didl:Component"][0]["didl:Resource"]["srw_dc:dcx"]["dcterms:accessRights"]
                article_dict["recordIdentifier"] = art["didl:Component"][0]["didl:Resource"]["srw_dc:dcx"]["dcx:recordIdentifier"]
                article_dict["identifier"] = art["didl:Component"][0]["didl:Resource"]["srw_dc:dcx"]["dc:identifier"]
                # Append newspaper-and metadata-specific data
                article_dict.update(metadata)
                list_articles.append(article_dict)
        except KeyError as e:
            continue

    return list_articles

def deep_get(dictionary, keys, default=None):
    return reduce(
        lambda d, key: d.get(key, default) if isinstance(d, dict) else default,
        keys.split("."),
        dictionary,
    )

# %%
test = parse_XML_metadata("/Users/leonardovida/dev/hist-aware/data/raw/delpher/1960s/1969/01-02/DDD_010690741/DDD:ddd:010690741:mpeg21.didl.xml.gz.xml", "dir", "name", 1)
test = pd.DataFrame(test)
test
# Out:
#                           subject  \
# 0                         artikel
# 1    illustratie met onderschrift
# 2                         artikel
# 3                         artikel
# 4                         artikel
# ..                            ...
# 191                   advertentie
# 192                   advertentie
# 193                   advertentie
# 194                   advertentie
# 195                   advertentie
#
#                                                  title access_rights  \
# 0    Na 2 uren onderhandelen Vietcong laat drie Ame...    accessible
# 1                                             ONTSNAPT    accessible
# 2                                             HET WEER    accessible
# 3                                                Zacht    accessible
# 4                                        Geen sancties    accessible
# ..                                                 ...           ...
# 191                                        Advertentie    accessible
# 192                                        Advertentie    accessible
# 193                                        Advertentie    accessible
# 194                                        Advertentie    accessible
# 195                                        Advertentie    accessible
#
#                recordIdentifier  \
# 0    ddd:010690741:mpeg21:a0001
# 1    ddd:010690741:mpeg21:a0002
# 2    ddd:010690741:mpeg21:a0003
# 3    ddd:010690741:mpeg21:a0004
# 4    ddd:010690741:mpeg21:a0005
# ..                          ...
# 191  ddd:010690741:mpeg21:a0061
# 192  ddd:010690741:mpeg21:a0062
# 193  ddd:010690741:mpeg21:a0063
# 194  ddd:010690741:mpeg21:a0064
# 195  ddd:010690741:mpeg21:a0065
#
#                                             identifier metadata_title  \
# 0    http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# 1    http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# 2    http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# 3    http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# 4    http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# ..                                                 ...            ...
# 191  http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# 192  http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# 193  http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# 194  http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
# 195  http://resolver.kb.nl/resolve?urn=ddd:01069074...           name
#
#            date  index                                           filepath  \
# 0    1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# 1    1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# 2    1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# 3    1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# 4    1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# ..          ...    ...                                                ...
# 191  1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# 192  1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# 193  1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# 194  1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
# 195  1969-01-02      1  /Users/leonardovida/dev/hist-aware/data/raw/de...
#
#      dir                                    newspaper_title newspaper_date  \
# 0    dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# 1    dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# 2    dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# 3    dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# 4    dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# ..   ...                                                ...            ...
# 191  dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# 192  dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# 193  dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# 194  dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
# 195  dir  Friese koerier : onafhankelĳk dagblad voor Fri...     1969-01-02
#
#                      newspaper_publisher newspaper_source newspaper_volume  \
# 0    Stichting Je Maintiendrai-Friesland         KB C 199               24
# 1    Stichting Je Maintiendrai-Friesland         KB C 199               24
# 2    Stichting Je Maintiendrai-Friesland         KB C 199               24
# 3    Stichting Je Maintiendrai-Friesland         KB C 199               24
# 4    Stichting Je Maintiendrai-Friesland         KB C 199               24
# ..                                   ...              ...              ...
# 191  Stichting Je Maintiendrai-Friesland         KB C 199               24
# 192  Stichting Je Maintiendrai-Friesland         KB C 199               24
# 193  Stichting Je Maintiendrai-Friesland         KB C 199               24
# 194  Stichting Je Maintiendrai-Friesland         KB C 199               24
# 195  Stichting Je Maintiendrai-Friesland         KB C 199               24
#
#     newspaper_issuenumber newspaper_recordIdentifier
# 0                      91       ddd:010690741:mpeg21
# 1                      91       ddd:010690741:mpeg21
# 2                      91       ddd:010690741:mpeg21
# 3                      91       ddd:010690741:mpeg21
# 4                      91       ddd:010690741:mpeg21
# ..                    ...                        ...
# 191                    91       ddd:010690741:mpeg21
# 192                    91       ddd:010690741:mpeg21
# 193                    91       ddd:010690741:mpeg21
# 194                    91       ddd:010690741:mpeg21
# 195                    91       ddd:010690741:mpeg21
#
# [196 rows x 17 columns]

# %%
from datetime import datetime
from functools import reduce
import re
import pathlib
import xmltodict
import xml.etree.ElementTree as et


def parse_XML_article(path, art_dir, title, index):
    """Parse the input XML file and store the result in a pandas
    DataFrame with the given columns.

    Takes the filepath, file title and index integer of the df
    """

    xtree = et.parse(path)
    xroot = xtree.getroot()
    list_articles = []

    # Parse the date with regex
    match = re.search(r"\d{4}[/]\d{2}[-]\d{2}", path)
    date = datetime.strptime(match.group(), "%Y/%m-%d").date()
    
    list_p = []
    article = {}
    for i, node in enumerate(xroot):
        article["article_name"] = str(title)
        article["date"] = str(date)
        article["index"] = index
        article["filepath"] = path
        article["dir"] = art_dir
        if node.tag == "title":
            article["title"] = node.text
        else:
            list_p.append(node.text)
    article["p"] = list_p
    list_p = []

    # Returns list of dict of articles and titles
    return article

# %%
a = parse_XML_article("/Users/leonardovida/dev/hist-aware/data/raw/delpher/1960s/1960/01-01/DDD_010872554/DDD_010872554_0001_articletext.xml", "dir", "title", "index")
b = parse_XML_article("/Users/leonardovida/dev/hist-aware/data/raw/delpher/1960s/1960/01-01/DDD_010872554/DDD_010872554_0001_articletext.xml", "dir", "title", "index")

# %%
import pandas as pd
list_articles = []
list_articles.append(a)
list_articles.append(b)
main = pd.DataFrame.from_dict(list_articles)

# %%
main
# Out:
#   article_name        date  index  \
# 0        title  1960-01-01  index
# 1        title  1960-01-01  index
#
#                                             filepath  dir             title  \
# 0  /Users/leonardovida/dev/hist-aware/data/raw/de...  dir  De zes en dertig
# 1  /Users/leonardovida/dev/hist-aware/data/raw/de...  dir  De zes en dertig
#
#                                                    p
# 0  [~Le dernier des justes", de laatste der Tsadd...
# 1  [~Le dernier des justes", de laatste der Tsadd...

# %%
import os
from tqdm.notebook import trange, tqdm


def iterate_directory(dir_path, file_type):
    """Iterate over the `path_dir` and its children and
    create a dictionary of
        - name
        - path
        - dir
    names of files found
    """
    file_names = {}
    list_names = []

    for subdir, dirs, files in os.walk(dir_path, topdown=True):
        for file in files:
            filepath = subdir + os.sep + file
            if filepath.endswith(str(file_type)):
                file_names["article_name"] = file
                file_names["article_path"] = filepath
                file_names["article_dir"] = subdir
                list_names.append(file_names)
                file_names = {}

    return list_names

PROC_ART_DECADE = "/Users/leonardovida/dev/hist-aware/data/processed/processed_articles/1960s"
PROC_MET_DECADE = "/Users/leonardovida/dev/hist-aware/data/processed/processed_metadata/1960s"
MERGED_DECADE = "/Users/leonardovida/dev/hist-aware/data/processed/merged_articles/1960s"
TOPIC = "gas"

def merge_metadata_articles():
    li = []
    
    csv_articles = iterate_directory(
            dir_path=os.path.join(PROC_ART_DECADE),
            file_type=".csv",
        )
    csv_articles = pd.DataFrame(csv_articles)
    csv_articles.rename(
        columns={
            "article_name": "csv_name",
            "article_path": "csv_path",
            "article_dir": "csv_dir",
        },
        inplace=True,
    )
    
    # Metadata
    df_metadata = pd.read_csv("/Users/leonardovida/dev/hist-aware/data/processed/processed_metadata/1960s/metadata0_10000.csv")
    df_metadata = df_metadata.head(10000)
    # print(df_metadata.columns.values)
    df_metadata.drop(columns=["date"], inplace=True)
    df_metadata.rename(
        columns={"filepath": "metadata_filepath", "index": "index_metadata"},
        inplace=True,
    )

    li = []
    # Load processed articles iteratively
    for i, row in tqdm(
        csv_articles.iterrows(), total=csv_articles.shape[0]
    ):
        csv_file = pd.read_csv(row["csv_path"])
        li.append(csv_file)
        if i % 28 == 0:
            df_articles = pd.concat(li, axis=0)
            df_articles.sort_values(by=["index"], ascending=True)
            df_articles.rename(
                columns={"filepath": "article_filepath", "index": "index_article"},
                inplace=True,
            )
            df_joined = df_articles.merge(df_metadata, how="left", on="title")
            df_joined.drop(columns=["Unnamed: 0", "Unnamed: 0_x", "Unnamed: 0_y"])
            NAME = TOPIC + "_" + str(i)
            NAME_JOINED = os.path.join(MERGED_DECADE, NAME)
            df_joined.to_csv(NAME_JOINED)
            li = []

    return None

# %%
a = pd.read_csv("/Users/leonardovida/dev/hist-aware/data/processed/merged_articles/1960s/gas_28")
print(a.columns.values)
# Out:
# ['Unnamed: 0' 'Unnamed: 0_x' 'article_name' 'date' 'index_article'
#  'article_filepath' 'dir_x' 'title' 'p' 'Unnamed: 0_y' 'subject'
#  'access_rights' 'recordIdentifier' 'identifier' 'metadata_title'
#  'index_metadata' 'metadata_filepath' 'dir_y' 'newspaper_title'
#  'newspaper_date' 'newspaper_publisher' 'newspaper_source'
#  'newspaper_volume' 'newspaper_issuenumber' 'newspaper_recordIdentifier']
