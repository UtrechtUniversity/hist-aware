# %% [markdown]
# # Similarity with fasttext

# %% [markdown]
# ### Load model

# %%
import csv

import fasttext
import fasttext.util
import pandas as pd
#fasttext.util.download_model('nl', if_exists='ignore')  # Dutch

# %%
ft = fasttext.load_model('cc.nl.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# ### Load train and test df

# %%
# Train
train = pd.read_csv("result.csv")
train.drop(columns={'label'}, inplace = True)
train.dropna(0, subset=["text_clean", "sentiment"], inplace = True)
cleanup_label = {"sentiment": {"Yes": 1, "No": 0}}
train.replace(cleanup_label, inplace=True)
train.rename(columns={"sentiment": "label"}, inplace=True)
train = train[train["type"] != "title"].copy()

# %%
# Test
# Load the previous dataset for testing
test = pd.read_csv("../data/processed/selected_articles/1990s/to_label_gas.csv")
test["label"] = None
# Drop labeled articles
test = test.loc[~test.index_article.isin(train.index_article)].copy()
# Drop na and titles
test.dropna(0, subset=["text_clean"], inplace = True)
test = test[test["type"] != "title"].copy()
# Out:
# 42816
# 42314
# 41257

# %% [markdown]
# ### Create train valid sets

# %%
# Split train and validation
from sklearn.model_selection import train_test_split
train_x, valid_x, train_y, valid_y = train_test_split(train["text_clean"], train["label"],
                                                  stratify=train["label"],
                                                  random_state=42, 
                                                  test_size=0.2, shuffle=True)

# %% [markdown]
# ### Create train and valid adding Over/Under sampling

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# define oversampling strategy
over = RandomOverSampler(sampling_strategy=0.5)
# fit and apply the transform
X, y = over.fit_resample(train[["text_clean"]], train[["label"]])
# define undersampling strategy
under = RandomUnderSampler(sampling_strategy=0.5)
# fit and apply the transform
X, y = under.fit_resample(X, y)

# %%
from sklearn.model_selection import train_test_split
train_x, valid_x, train_y, valid_y = train_test_split(X, y,
                                                  stratify=y,
                                                  random_state=42, 
                                                  test_size=0.2, shuffle=True)

# %% [markdown]
# ### Create txt for fasttext

# %%
file = open('gas.1990.train', 'w+')
for idx, row in train_x.items():
    line = '__label__' + str(train_y[idx]) + ' ' + train_x[idx]
    file.write(line + '\n')
    
file = open('gas.1990.valid', 'w+')
for idx, row in valid_x.items():
    line = '__label__' + str(valid_y[idx]) + ' ' + valid_x[idx]
    file.write(line + '\n')

# %%
file = open('gas.1990.train.ou', 'w+')
for idx, row in train_x.items():
    line = '__label__' + str(train_y[idx]) + ' ' + train_x[idx]
    file.write(line + '\n')
    
file = open('gas.1990.valid.ou', 'w+')
for idx, row in valid_x.items():
    line = '__label__' + str(valid_y[idx]) + ' ' + valid_x[idx]
    file.write(line + '\n')
# Out:
# ----------------------------------------------------------------
# KeyError                       Traceback (most recent call last)
# ~/Library/Caches/pypoetry/virtualenvs/histaware-RplM6c3o-py3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text_clean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                       Traceback (most recent call last)
# <ipython-input-105-e53af9a51b86> in <module>
#       1 file = open('gas.1990.train.ou', 'w+')
#       2 for idx, row in train_x.items():
# ----> 3     line = '__label__' + str(train_y[idx]) + ' ' + train_x[idx]
#       4     file.write(line + '\n')
#       5
#
# ~/Library/Caches/pypoetry/virtualenvs/histaware-RplM6c3o-py3.8/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/Library/Caches/pypoetry/virtualenvs/histaware-RplM6c3o-py3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'text_clean'

# %% [markdown]
# ### Train fasttext model

# %%
model = fasttext.train_supervised(input="train.txt", lr=0.0001, epoch=10000, wordNgrams=1, bucket=200000, dim=400, loss='hs')

# %%
model_2 = fasttext.train_supervised(input="gas.1990.train", autotuneValidationFile='gas.1990.valid', autotuneDuration=300)

# %%
model_2.save_model("model.gas.1990")

# %%
model_2.test('gas.1990.valid')
# Out:
# (68, 0.8970588235294118, 0.8970588235294118)

# %% [markdown]
# ### Predict

# %%
list_preds = []
a = 0
for i, r in test.iterrows():
    print(row["text_clean"])
    #temp = model.predict(row["text_clean"])
    a = a + 1
    if a > 5: break
    list_preds.append(temp)
# Out:
# het van organiseert dit jaar de landelijke dagen bij de in vanmiddag wijden de honderd deelnemers zich aan het het is de bedoeling dat dit spel de de verbetert het weekend trekken de deelnemers naar waar de vaardigheden om te werken worden getraind
# het van organiseert dit jaar de landelijke dagen bij de in vanmiddag wijden de honderd deelnemers zich aan het het is de bedoeling dat dit spel de de verbetert het weekend trekken de deelnemers naar waar de vaardigheden om te werken worden getraind
# het van organiseert dit jaar de landelijke dagen bij de in vanmiddag wijden de honderd deelnemers zich aan het het is de bedoeling dat dit spel de de verbetert het weekend trekken de deelnemers naar waar de vaardigheden om te werken worden getraind
# het van organiseert dit jaar de landelijke dagen bij de in vanmiddag wijden de honderd deelnemers zich aan het het is de bedoeling dat dit spel de de verbetert het weekend trekken de deelnemers naar waar de vaardigheden om te werken worden getraind
# het van organiseert dit jaar de landelijke dagen bij de in vanmiddag wijden de honderd deelnemers zich aan het het is de bedoeling dat dit spel de de verbetert het weekend trekken de deelnemers naar waar de vaardigheden om te werken worden getraind
# het van organiseert dit jaar de landelijke dagen bij de in vanmiddag wijden de honderd deelnemers zich aan het het is de bedoeling dat dit spel de de verbetert het weekend trekken de deelnemers naar waar de vaardigheden om te werken worden getraind

# %%
list_preds
# Out:
# [(('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  (('__label__0',), array([0.67702383])),
#  ...]

# %%
test["label"]
# Out:
# 19       ((__label__0,), [0.6770238280296326])
# 37       ((__label__0,), [0.6770238280296326])
# 133      ((__label__0,), [0.6770238280296326])
# 141      ((__label__0,), [0.6770238280296326])
# 172      ((__label__0,), [0.6770238280296326])
#                          ...
# 42811    ((__label__0,), [0.6770238280296326])
# 42812    ((__label__0,), [0.6770238280296326])
# 42813    ((__label__0,), [0.6770238280296326])
# 42814    ((__label__0,), [0.6770238280296326])
# 42815    ((__label__0,), [0.6770238280296326])
# Name: label, Length: 41350, dtype: object

# %%
i = 900
print(test["text"][i])
print(model.predict(test["text_clean"][i]))
#print(test.iloc[3,1].values)
# Out:
# • V^y energiebesparing! doet u er iets aan?^S^//| _^_^_H_H_te m^l^L^Ê WÊL^ Tei< onderstaande bedrijven helpen u graag op weg. V*"^=__^ £ ' ft _— -------- . ,V1U BRUNSSUM' 9e; BRUNSSUM: ___ri^_i__riV llWllTi 11 Als uw woning gemiddeld 2.000 m 3 aard- ou . ]*•» _r A _■ Al I V kil '•' — _r W . ■ I ■ I I _ w I _ I F__l_P_F TJJ -J.\! r_-J T 3 5 Installatiebedrijf I____&_m_l lU gas per jaar nodig heeft voor verwarming, _»ftTM.C7:Vg»I H ■ vilij w* A. Hermse b.v. Frans Goeman ° 'Mll [Il ij f 111 ■■ il 1 l*J dan kiest u 00k voor de nieuwe Landelijk erkend install^ Ï;J Pr. Hendriklaan 172 _W i ■ lil lw II fli _I k I lw I B^ 1 voor gas, water en sanitair 15.; __J_ii U_____l ____________J_l___l Thermocompact Low NOx CV-ketel van Horizonstraat 55 i«j ■,'I _TiT_ _',<_■ il I ll_!_BT»i wv —A'V'l Br1»^! -x '6i I __LJJ L^^^^^^^^3_^__^_^_^__l_T«__^__^__id____^__i^__A__^__| I Vaillant: » 17. CADIER EN KEER: DE KAMPIOEN BIJ EEN GEMIDDELD GAS- HEERLEN: ie. WSSt rr Installatiebedrijf \\ i^P %?n! verbruik van 2.000 m 3 18v J. Gilissen b.v. V__. Vlek Verwarming b.v- ie, üi ' Kampioen in schone verbranding, kampioen „ ö Heerderweg3 m f^\ Litscherveldweg 8 19 Tel. 04407-2220 !'• J 1" W& Tel. 045-212057 c I_'. '_A. HV P^J_l in lage gebruikskosten en dat met een zeer «5 _W __k ~_ BI w>v//H^H I —Hf _l^m. _dr »*%' <*r ' mam § 4 i\JI/ gunstig rendement. Voordelig in aanschaf HEERLEN: \ HEERLEN: jflfjf \ _■ \ \ili\f Vfa h schraa *zn 0! ■mmmW^9 J__KV K 1 ƒ_F* I / _^_-p* _J _ ii _ i j. (_ FA. H. SCHRAA & ZN. /.„. m' pM i _B Vkf jdfi fill//^? en installatie. Leverbaar in open en gesloten jj*r -^ i Technisch Bureau 4 fJf J lf/ff7_»-%v I W* Centrale ■^ Frissen b.V. -WW ïj^lt' \ V uitvoering. Met of zonder warm water. \f oeiurdie niaaciiu.w. rjlp m* -^m^-^1 9 verwarming / sanitair * Lintjensstraat 17 WS %,^< Ons advies? De Vaillant Thermocompact p^ loodgietersbedrijf Tel. 045-717318 «Ë_____________3 Ml Jon9manswe947 ft ÊÊm^St^ Low NOxis Precies wat u zoekt- SPr TeL 045212203 ; HEERLEN: ■___■ -^ I^^HH_-___-____ I_?AS*XE ___,' HOENSBROEK: Installatiebdrijf * Wm Gosink Techniek b.v. ! Lemmens-Meessen b.v. i_l>» 1 VAILLANT GEEFT MEER Industriestraat 29 Litscherveldweg 2 Tel. 045-218242 Tel. 045-213661 WAARDE AAN UW HUIS ■ 1 ■■■I m . Hfc \ fWI KERKRADE: - " " fWjl LANDGRAAF: I Installatiebdrijf _L- Installatiebedrijf A. PLoem & Zn. BV *f* Vaillant BV, Postbus 23250 J. Criits Grupellostraat3l-33 1100 DT Amsterdam Zuidoost Tel. 045-452841 . Wattstraat 22 24-uurs servicedienst _^_^_^B_^_^_^_^_^_^^^^^^^^HBB_^_^_^_^_^_^_^_i_^_^^^^b^^^^^^^^^^^^ Tel. 045-318641 U KUNT ONS GELIJK BELLEN y MARGRATEN: MECHELEN: NUTH: SITTARD: SITTARD: SITTARD: _* ,> JP fi!sbg^sbednjf F 4 ,irma ÜTI Warmwatertechnisch j^A _/>^ F K^ F,rma BiM Installatieburo ,«w«-^ :MWI ERLI J N gas water sanitair centr. Math Linssen VOF Dom v.d. Bergh r uon de Rmck RV _? L*°" V-cuat** ■■■—™ VERWARMING ALLE SOORTEN S H. Van Ue DrOCK BV Rijksweg 70 "mÏnmhergie-S * Bergerweg 20 • Voorstad 5 Stationsplein 16 Rijksweg Zuid 101 Tel. 04458-1609 Tel. 045-241587 Tel. 046-510630 Tel. 046-512470. 6134 AA Sittard Fax:04458-2844 Mecnoibeokiaan 9 - 6281 nr Mecheien - 24-uursservice Telefoon 046-5125»^ 1 L—_________________ : :
# (('__label__0',), array([0.75938559]))
