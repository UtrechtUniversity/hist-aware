# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cleaned_df.csv")
df_copy = df.copy()
df_copy.rename(columns = {"text": "abstract"}, inplace=True)
df_copy.head(2)
df_copy.to_csv("test_df.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(14, 6))
ax = sns.countplot(x="newspaper_source",data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'KB C 98'),
#  Text(1, 0, 'Sociaal Historisch centrum voor Limburg T 501'),
#  Text(2, 0, 'Koninklijke Bibliotheek C 236'),
#  Text(3, 0, 'Koninklijke Bibliotheek'),
#  Text(4, 0, 'KB C 199'),
#  Text(5, 0, 'Koninklijke Bibliotheek MM03C-101551'),
#  Text(6, 0, 'Gemeentearchief Rotterdam'),
#  Text(7, 0, 'Koninklijke Bibliotheek MM03C-101553'),
#  Text(8, 0, 'Koninklijke Bibliotheek MM03C-101552'),
#  Text(9, 0, 'KB C 937'),
#  Text(10, 0, 'KB C 197'),
#  Text(11, 0, 'Koninklijk Instituut voor de Tropen (KIT) L5016'),
#  Text(12, 0, 'Internationaal Instituut voor Sociale Geschiedenis ZF 40364'),
#  Text(13, 0, 'Koninklijk Instituut voor de Tropen (KIT) L 5000'),
#  Text(14, 0, 'Koninklijke Bibliotheek NBM C 1136'),
#  Text(15, 0, 'Groninger archieven 649-1316'),
#  Text(16, 0, 'KB C 251'),
#  Text(17, 0, 'Tresoar'),
#  Text(18, 0, 'Nederlands Dagblad'),
#  Text(19, 0, 'Koninklijke Bibliotheek C 251'),
#  Text(20, 0, 'Groninger archieven 649-1319'),
#  Text(21, 0, 'Koninklijke Bibliotheek 1608 C 7'),
#  Text(22, 0, 'Groninger archieven 649-1318'),
#  Text(23, 0, 'Roosevelt Study Center')]

# %%
ax = sns.countplot(x="count",data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '1'),
#  Text(1, 0, '2'),
#  Text(2, 0, '3'),
#  Text(3, 0, '4'),
#  Text(4, 0, '5'),
#  Text(5, 0, '6'),
#  Text(6, 0, '7'),
#  Text(7, 0, '9'),
#  Text(8, 0, '12'),
#  Text(9, 0, '13'),
#  Text(10, 0, '19'),
#  Text(11, 0, '22')]

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0_x type  \
# 0             0         40995    p
# 1             1         27756    p
# 2             2        122267    p
# 3             3         36288    p
# 4             4         90947    p
# ..          ...           ...  ...
# 910         388         66431    p
# 911         389         64745    p
# 912         390         64399    p
# 913         391         63841    p
# 914         914        135657    p
#
#                                                   text  \
# 0    AMSTERDAM. 13 Nov. — (Coörj. Tuir.dersveilingv...
# 1    AMSTERDAM, 28 Nov. — Groente. tCoöp. Tuindersv...
# 2    GROENTENVEILING LEEUWARDEN 5 Juni. Andijvie B—...
# 3    Aoiang er mijnen bestaan is het mijngas de gro...
# 4    NAALDWIJK, 6 Dec. — Groente Alleanten 1.09—1.3...
# ..                                                 ...
# 910  (Advertentie) CarboTit beschermt leTen en gezo...
# 911  Aan vrienden en kennissen,. £:sl9rst*^Sfi2'ffl...
# 912  Donderdag 14 September. 15.00 uur Faun: Algeme...
# 913  N Gist *So A 315* 312' i N. Instr. Nieaf 140 t...
# 914  Donderdag 1 en Vrijdag 2 Juni zal het Koninkli...
#
#                            article_name        date  index_article  \
# 0    DDD_110585201_0106_articletext.xml  1950-11-16         115308
# 1    DDD_110585212_0127_articletext.xml  1950-11-29         110407
# 2    DDD_010612675_0107_articletext.xml  1950-06-07         144734
# 3    DDD_010417712_0100_articletext.xml  1950-11-16         113601
# 4    DDD_110585219_0073_articletext.xml  1950-12-07         133379
# ..                                  ...         ...            ...
# 910  DDD_010417714_0020_articletext.xml  1950-11-18         124556
# 911  DDD_011210810_0003_articletext.xml  1950-09-13         123963
# 912  DDD_010887169_0040_articletext.xml  1950-09-13         123813
# 913  DDD_110585146_0145_articletext.xml  1950-09-13         123589
# 914  DDD_010537284_0012_articletext.xml  1950-05-16         149828
#
#                                       article_filepath  \
# 0    ../data/1950/11-16/DDD_110585201/DDD_110585201...
# 1    ../data/1950/11-29/DDD_110585212/DDD_110585212...
# 2    ../data/1950/06-07/DDD_010612675/DDD_010612675...
# 3    ../data/1950/11-16/DDD_010417712/DDD_010417712...
# 4    ../data/1950/12-07/DDD_110585219/DDD_110585219...
# ..                                                 ...
# 910  ../data/1950/11-18/DDD_010417714/DDD_010417714...
# 911  ../data/1950/09-13/DDD_011210810/DDD_011210810...
# 912  ../data/1950/09-13/DDD_010887169/DDD_010887169...
# 913  ../data/1950/09-13/DDD_110585146/DDD_110585146...
# 914  ../data/1950/05-16/DDD_010537284/DDD_010537284...
#
#                                   dir  Unnamed: 0_y  ...  \
# 0    ../data/1950/11-16/DDD_110585201         896.0  ...
# 1    ../data/1950/11-29/DDD_110585212         859.0  ...
# 2    ../data/1950/06-07/DDD_010612675           NaN  ...
# 3    ../data/1950/11-16/DDD_010417712         882.0  ...
# 4    ../data/1950/12-07/DDD_110585219          26.0  ...
# ..                                ...           ...  ...
# 910  ../data/1950/11-18/DDD_010417714         964.0  ...
# 911  ../data/1950/09-13/DDD_011210810         958.0  ...
# 912  ../data/1950/09-13/DDD_010887169         957.0  ...
# 913  ../data/1950/09-13/DDD_110585146         955.0  ...
# 914  ../data/1950/05-16/DDD_010537284           NaN  ...
#
#                                   newspaper_source  newspaper_volume  \
# 0                                          KB C 98              53.0
# 1                                          KB C 98              53.0
# 2                                              NaN               NaN
# 3    Sociaal Historisch centrum voor Limburg T 501              33.0
# 4                                          KB C 98              53.0
# ..                                             ...               ...
# 910  Sociaal Historisch centrum voor Limburg T 501              33.0
# 911             Koninklijke Bibliotheek NBM C 1136               2.0
# 912                   Groninger archieven 649-1318              63.0
# 913                                        KB C 98              53.0
# 914                                            NaN               NaN
#
#     newspaper_issuenumber newspaper_language count non_jkc  \
# 0                 19680.0                 nl    22    True
# 1                 19691.0                 nl    19    True
# 2                     NaN                NaN    13    True
# 3                   269.0                 nl    13    True
# 4                 19698.0                 nl    12    True
# ..                    ...                ...   ...     ...
# 910                 271.0                 nl     1    True
# 911                 294.0                 nl     1    True
# 912                 214.0                 nl     1    True
# 913               19625.0                 nl     1    True
# 914                   NaN                NaN     1    True
#
#                                             text_clean  \
# 0    AMSTERDAM.  Nov. — Coörj. Tir.dersveilingverg....
# 1    AMSTERDAM  Nov. — Groente. tCoöp. Tindersveili...
# 2    GROENTENVEILING LEEUWARDEN  Jni. Andijvie B—l ...
# 3    Aoiang er mijnen bestaan is het mijngas de gro...
# 4    NAALDWIJK  Dec. — Groente Alleanten .—.. handa...
# ..                                                 ...
# 910  Advertentie CarboTit beschermt leTen en gezond...
# 911  Aan vrienden en kennissen. £slrstSfifflS®®fS£S...
# 912  Donderdag  September. . r Fan Algemene vergade...
# 913  N Gist So A   i N. Instr. Nieaf  t  t Ned Kabe...
# 914  Donderdag  en Vrijdag  Jni zal het Koninklijk ...
#
#                                          text_no_point  \
# 0    AMSTERDAM Nov Co rj Tir dersveilingverg Amster...
# 1    AMSTERDAM Nov Groente tCo Tindersveilingverg A...
# 2    GROENTENVEILING LEEUWARDEN Jni Andijvie et per...
# 3    Aoiang er mijnen bestaan is het mijngas de gro...
# 4    NAALDWIJK Dec Groente Alleanten handappelen an...
# ..                                                 ...
# 910  Advertentie CarboTit beschermt leTen en gezond...
# 911  Aan vrienden en kennissen slrstSfifflS fS Sysi...
# 912  Donderdag September Fan Algemene vergadering v...
# 913  Gist So Instr Nieaf Ned Kabelt cA Ned Mij Hav ...
# 914  Donderdag en Vrijdag Jni zal het Koninklijk Pa...
#
#                                       text_clean_split  \
# 0    ['AMSTERDAM. Nov. — Coörj. Tir.dersveilingverg...
# 1    ['AMSTERDAM Nov. — Groente. tCoöp. Tindersveil...
# 2    ['GROENTENVEILING LEEUWARDEN Jni. Andijvie B—l...
# 3    ['Aoiang er mijnen bestaan is het mijngas de g...
# 4    ['NAALDWIJK Dec. — Groente Alleanten .—.. hand...
# ..                                                 ...
# 910  ['Advertentie CarboTit beschermt leTen en gezo...
# 911  ['Aan vrienden en kennissen. £slrstSfifflS®®fS...
# 912  ['Donderdag September. . r Fan Algemene vergad...
# 913  ['N Gist So A i N. Instr. Nieaf t t Ned Kabelt...
# 914  ['Donderdag en Vrijdag Jni zal het Koninklijk ...
#
#                              text_clean_split_no_point
# 0    ['AMSTERDAM Nov Co rj Tir dersveilingverg Amst...
# 1    ['AMSTERDAM Nov Groente tCo Tindersveilingverg...
# 2    ['GROENTENVEILING LEEUWARDEN Jni Andijvie et p...
# 3    ['Aoiang er mijnen bestaan is het mijngas de g...
# 4    ['NAALDWIJK Dec Groente Alleanten handappelen ...
# ..                                                 ...
# 910  ['Advertentie CarboTit beschermt leTen en gezo...
# 911  ['Aan vrienden en kennissen slrstSfifflS fS Sy...
# 912  ['Donderdag September Fan Algemene vergadering...
# 913  ['Gist So Instr Nieaf Ned Kabelt cA Ned Mij Ha...
# 914  ['Donderdag en Vrijdag Jni zal het Koninklijk ...
#
# [915 rows x 27 columns]
