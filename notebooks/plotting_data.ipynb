# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cleaned_df.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16, 6))
ax = sns.countplot(x="newspaper_source",data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Sociaal Historisch centrum voor Limburg T 501'),
#  Text(1, 0, 'Koninklijke Bibliotheek C 236'),
#  Text(2, 0, 'Gemeentearchief Rotterdam'),
#  Text(3, 0, 'KB C 98'),
#  Text(4, 0, 'Koninklijke Bibliotheek MM03C-101553'),
#  Text(5, 0, 'Koninklijke Bibliotheek MM03C-101551'),
#  Text(6, 0, 'Internationaal Instituut voor Sociale Geschiedenis ZF 40364'),
#  Text(7, 0, 'Koninklijke Bibliotheek C 251'),
#  Text(8, 0, 'Koninklijke Bibliotheek NBM C 1136'),
#  Text(9, 0, 'KB C 251'),
#  Text(10, 0, 'Koninklijke Bibliotheek'),
#  Text(11, 0, 'KB C 937'),
#  Text(12, 0, 'Groninger archieven 649-1316'),
#  Text(13, 0, 'KB C 197'),
#  Text(14, 0, 'Koninklijk Instituut voor de Tropen (KIT) L 5000'),
#  Text(15, 0, 'Koninklijke Bibliotheek 1608 C 7'),
#  Text(16, 0, 'Koninklijk Instituut voor de Tropen (KIT) L5016'),
#  Text(17, 0, 'Nederlands Dagblad'),
#  Text(18, 0, 'Tresoar'),
#  Text(19, 0, 'Koninklijke Bibliotheek MM03C-101552'),
#  Text(20, 0, 'KB C 199'),
# ...
