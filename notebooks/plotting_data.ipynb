# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cleaned_df.csv")
df_copy = df.copy()
df_copy.rename(columns = {"text": "abstract"}, inplace=True)
df_copy.head(2)
df_copy.to_csv("test_df.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(14, 6))
ax = sns.countplot(x="newspaper_source",data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'KB C 101'),
#  Text(1, 0, 'KB C 98'),
#  Text(2, 0, 'Koninklijke Bibliotheek'),
#  Text(3, 0, 'Groninger archieven'),
#  Text(4, 0, 'Nederlands Dagblad'),
#  Text(5, 0, 'Sociaal Historisch centrum voor Limburg T 501'),
#  Text(6, 0, 'KB C 251'),
#  Text(7, 0, 'Gemeentearchief Rotterdam'),
#  Text(8, 0, 'Koninklijke Bibliotheek C 236'),
#  Text(9, 0, 'KB  C 98'),
#  Text(10, 0, 'Koninklijke Bibliotheek 1608 C 7'),
#  Text(11, 0, 'Internationaal Instituut voor Sociale Geschiedenis ZF 40364'),
#  Text(12, 0, 'KB C 937'),
#  Text(13, 0, 'Koninklijke Bibliotheek C 98'),
#  Text(14, 0, 'Groninger archieven 649-1316'),
#  Text(15, 0, 'Koninklijke Bibliotheek NBM C 1136'),
#  Text(16, 0, 'Koninklijke Bibliotheek TG 30016'),
#  Text(17, 0, 'KB C 199'),
#  Text(18, 0, 'Tresoar'),
#  Text(19, 0, 'Koninklijke Bibliotheek MM03C-101551'),
#  Text(20, 0, 'Groninger archieven 649-1318'),
#  Text(21, 0, 'Groninger archieven 649-1319'),
#  Text(22, 0, 'Koninklijke Bibliotheek MM03C-101552'),
#  Text(23, 0, 'Koninklijk Instituut voor de Tropen (KIT) L 5000'),
#  Text(24, 0, 'KB C 197'),
#  Text(25, 0, 'Koninklijke Bibliotheek MM03C-101553'),
#  Text(26, 0, 'Koninklijke Bibliotheek C 251'),
#  Text(27, 0, 'Koninklijk Instituut voor de Tropen (KIT) L5016'),
#  Text(28, 0, 'Roosevelt Study Center')]

# %%
ax = sns.countplot(x="count",data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '1'),
#  Text(1, 0, '2'),
#  Text(2, 0, '3'),
#  Text(3, 0, '4'),
#  Text(4, 0, '5'),
#  Text(5, 0, '6'),
#  Text(6, 0, '7'),
#  Text(7, 0, '8'),
#  Text(8, 0, '9'),
#  Text(9, 0, '10'),
#  Text(10, 0, '11'),
#  Text(11, 0, '12'),
#  Text(12, 0, '13'),
#  Text(13, 0, '14'),
#  Text(14, 0, '15'),
#  Text(15, 0, '16'),
#  Text(16, 0, '18'),
#  Text(17, 0, '19'),
#  Text(18, 0, '21'),
#  Text(19, 0, '22'),
#  Text(20, 0, '27'),
#  Text(21, 0, '28'),
#  Text(22, 0, '29'),
#  Text(23, 0, '30')]
